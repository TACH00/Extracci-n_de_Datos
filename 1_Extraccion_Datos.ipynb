# %% [markdown]
# <a href="https://colab.research.google.com/github/NachoSabritas/HolaMundo/blob/main/1_Extraccion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
df=pd.read_csv("file.csv")
df
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# 1        2005          1           Nacional  Mujeres
# 2        2005          1     Aguascalientes  Hombres
# 3        2005          1     Aguascalientes  Mujeres
# 4        2005          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# ...

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)

# %%
#filtros por objeto
filtro1=df[df ["Entidad_Federativa"] == "Puebla"]
filtro1

# %%
#Filtro por filas
#filtro2=df.iloc[300:302,: ]#filas consecutivas
filtro2=df.iloc[[1000, 2000, 3000], : ] #Filas no consecutivas
filtro2

# %%
#Filtro por columnas
#filtro3=df.iloc[ : ,4:6]#Columnas consecutivas
filtro3=df.iloc[ : ,[1, 4, 6]] #Columnas no consecutivas
filtro3

# %%
#Filtro mixto (filas y columnas)
filtro_mix = df.iloc[[10, 20, 50], 2:5]
filtro_mix

# %%
#Filtro de filas vs columnas
#Paso 1: leemos el contenido del archivo seleccionado previamente
from google.colab import files
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded["file.csv"]),index_col=2)
df

# %%
#Paso 2: Aplicamos filtro de filas vs columnas
filtro4=df.loc[["Puebla","Durango"], ["Poblacion_ocupada_en_la_industria_manufacturera" ]]
filtro4

# %%
#Filtro para comparacion
filtro6=df[df["Periodo"] >2006]
filtro6

# %%
#Filtro Y
filtro7 = df[(df['Periodo'] == 2015) & (df['Sexo'] == 'Hombres') & (df['Entidad_Federativa'] == 'Chiapas') & (df['Trimestre'] == 3)]
filtro7
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 2786     2015          3            Chiapas  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 2786                                           76655           1358553
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 2786                        5.6424004070000000000000

# %%
#Filtro o
filtro8 = df[(df["Periodo"] > 2006) | (df["Sexo"] == "Mujeres")]
filtro8

# %%
#Filtro not
filtro9 = df[~(df["Periodo"] >= 2006) & ~(df["Sexo"] == "Mujeres")]
filtro9
